# %% [markdown]
# # Use Case:  Language Translator
# dataset consisting of pairs of English sentences and their French translation,

# %%
from __future__ import print_function

from keras.models import Model
from keras.layers import Input, LSTM, Dense
import numpy as np

# %%
batch_size = 64  # Batch size for training.
epochs = 100  # Number of epochs to train for.
latent_dim = 256  # Latent dimensionality of the encoding space.
num_samples = 10000  # Number of samples to train on.
# Path to the data txt file on disk.
data_path = 'fra-eng/fra.txt'

# %%
# Vectorize the data.
input_texts = []
target_texts = []
input_characters = set()
target_characters = set()
with open(data_path, 'r', encoding='utf-8') as f:
    lines = f.read().split('\n')

# %%
for line in lines[: min(num_samples, len(lines) - 1)]:
    input_text, target_text, _ = line.split('\t')
    # We use "tab" as the "start sequence" character
    # for the targets, and "\n" as "end sequence" character.
    target_text = '\t' + target_text + '\n'
    input_texts.append(input_text)
    target_texts.append(target_text)
    for char in input_text:
        if char not in input_characters:
            input_characters.add(char)
    for char in target_text:
        if char not in target_characters:
            target_characters.add(char)

# %%
input_characters = sorted(list(input_characters))
target_characters = sorted(list(target_characters))
num_encoder_tokens = len(input_characters)
num_decoder_tokens = len(target_characters)
max_encoder_seq_length = max([len(txt) for txt in input_texts])
max_decoder_seq_length = max([len(txt) for txt in target_texts])

# %%
print('Number of samples:', len(input_texts))
print('Number of unique input tokens:', num_encoder_tokens)
print('Number of unique output tokens:', num_decoder_tokens)
print('Max sequence length for inputs:', max_encoder_seq_length)
print('Max sequence length for outputs:', max_decoder_seq_length)
# Out:
# Number of samples: 10000
# Number of unique input tokens: 71
# Number of unique output tokens: 93
# Max sequence length for inputs: 16
# Max sequence length for outputs: 59

# %%
input_token_index = dict(
    [(char, i) for i, char in enumerate(input_characters)])
target_token_index = dict(
    [(char, i) for i, char in enumerate(target_characters)])

# %%
"""Turn the sentences into 3 Numpy arrays, encoder_input_data, decoder_input_data, decoder_target_data:

encoder_input_data is a 3D array of shape (num_pairs, max_english_sentence_length, num_english_characters) containing a one-hot vectorization of the English sentences
decoder_input_data is a 3D array of shape (num_pairs, max_french_sentence_length, num_french_characters) containing a one-hot vectorization of the French sentences
decoder_target_data is the same as decoder_input_data but offset by one timestep. decoder_target_data[:, t, :] will be the same as decoder_input_data[:, t + 1, :]
"""

encoder_input_data = np.zeros((len(input_texts), max_encoder_seq_length, num_encoder_tokens),dtype='float32')
decoder_input_data = np.zeros((len(input_texts), max_decoder_seq_length, num_decoder_tokens),dtype='float32')
decoder_target_data = np.zeros((len(input_texts), max_decoder_seq_length, num_decoder_tokens),dtype='float32')

# %%
for i, (input_text, target_text) in enumerate(zip(input_texts, target_texts)):
    for t, char in enumerate(input_text):
        encoder_input_data[i, t, input_token_index[char]] = 1.
    encoder_input_data[i, t + 1:, input_token_index[' ']] = 1.
    for t, char in enumerate(target_text):
        # decoder_target_data is ahead of decoder_input_data by one timestep
        decoder_input_data[i, t, target_token_index[char]] = 1.
        if t > 0:
            # decoder_target_data will be ahead by one timestep
            # and will not include the start character.
            decoder_target_data[i, t - 1, target_token_index[char]] = 1.
    decoder_input_data[i, t + 1:, target_token_index[' ']] = 1.
    decoder_target_data[i, t:, target_token_index[' ']] = 1.

# %%
# Define an input sequence and process it.
encoder_inputs = Input(shape=(None, num_encoder_tokens))
encoder = LSTM(latent_dim, return_state=True)
encoder_outputs, state_h, state_c = encoder(encoder_inputs)
# We discard `encoder_outputs` and only keep the states.
encoder_states = [state_h, state_c]
# Out:
# WARNING:tensorflow:From c:\users\lenovo\appdata\local\programs\python\python36\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
# Set up the decoder, using `encoder_states` as initial state.
decoder_inputs = Input(shape=(None, num_decoder_tokens))
# We set up our decoder to return full output sequences,
# and to return internal states as well. We don't use the
# return states in the training model, but we will use them in inference.
decoder_lstm = LSTM(latent_dim, return_sequences=True, return_state=True)
decoder_outputs, _, _ = decoder_lstm(decoder_inputs,
                                     initial_state=encoder_states)
decoder_dense = Dense(num_decoder_tokens, activation='softmax')
decoder_outputs = decoder_dense(decoder_outputs)

# %%
#Train a basic LSTM-based Seq2Seq model to predict decoder_target_data given encoder_input_data and decoder_input_data

# Define the model that will turn
# `encoder_input_data` & `decoder_input_data` into `decoder_target_data`
model = Model([encoder_inputs, decoder_inputs], decoder_outputs)

# %%
# Run training
model.compile(optimizer='rmsprop', loss='categorical_crossentropy',
              metrics=['accuracy'])
model.fit([encoder_input_data, decoder_input_data], decoder_target_data,
          batch_size=batch_size,
          epochs=epochs,
          validation_split=0.2)
# Save model
model.save('s2s.h5')
# Out:
# WARNING:tensorflow:From c:\users\lenovo\appdata\local\programs\python\python36\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# WARNING:tensorflow:From c:\users\lenovo\appdata\local\programs\python\python36\lib\site-packages\tensorflow\python\ops\math_grad.py:102: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# Train on 8000 samples, validate on 2000 samples
# Epoch 1/100
# 8000/8000 [==============================] - 48s 6ms/step - loss: 1.1699 - accuracy: 0.7255 - val_loss: 1.0631 - val_accuracy: 0.7139
# Epoch 2/100
# 8000/8000 [==============================] - 46s 6ms/step - loss: 0.8508 - accuracy: 0.7713 - val_loss: 0.8354 - val_accuracy: 0.7677
# Epoch 3/100
# 8000/8000 [==============================] - 45s 6ms/step - loss: 0.6839 - accuracy: 0.8077 - val_loss: 0.7242 - val_accuracy: 0.7917
# Epoch 4/100
# 8000/8000 [==============================] - 47s 6ms/step - loss: 0.5965 - accuracy: 0.8260 - val_loss: 0.6524 - val_accuracy: 0.8082
# Epoch 5/100
# 8000/8000 [==============================] - 48s 6ms/step - loss: 0.5481 - accuracy: 0.8401 - val_loss: 0.6414 - val_accuracy: 0.8092
# Epoch 6/100
# 8000/8000 [==============================] - 47s 6ms/step - loss: 0.5112 - accuracy: 0.8503 - val_loss: 0.5819 - val_accuracy: 0.8268
# Epoch 7/100
# 8000/8000 [==============================] - 46s 6ms/step - loss: 0.4816 - accuracy: 0.8577 - val_loss: 0.5584 - val_accuracy: 0.8344
# Epoch 8/100
# 8000/8000 [==============================] - 48s 6ms/step - loss: 0.4578 - accuracy: 0.8641 - val_loss: 0.5441 - val_accuracy: 0.8390
# Epoch 9/100
# 8000/8000 [==============================] - 47s 6ms/step - loss: 0.4365 - accuracy: 0.8696 - val_loss: 0.5226 - val_accuracy: 0.8451
# Epoch 10/100
# 8000/8000 [==============================] - 46s 6ms/step - loss: 0.4177 - accuracy: 0.8749 - val_loss: 0.5044 - val_accuracy: 0.8501
# Epoch 11/100
# 8000/8000 [==============================] - 47s 6ms/step - loss: 0.4003 - accuracy: 0.8801 - val_loss: 0.4965 - val_accuracy: 0.8534
# Epoch 12/100
# 8000/8000 [==============================] - 22s 3ms/step - loss: 0.3844 - accuracy: 0.8847 - val_loss: 0.4798 - val_accuracy: 0.8573
# Epoch 13/100
# 8000/8000 [==============================] - 21s 3ms/step - loss: 0.3691 - accuracy: 0.8892 - val_loss: 0.4722 - val_accuracy: 0.8593
# Epoch 14/100
# 8000/8000 [==============================] - 21s 3ms/step - loss: 0.3560 - accuracy: 0.8931 - val_loss: 0.4692 - val_accuracy: 0.8603
# Epoch 15/100
# 8000/8000 [==============================] - 21s 3ms/step - loss: 0.3425 - accuracy: 0.8972 - val_loss: 0.4584 - val_accuracy: 0.8629
# Epoch 16/100
# 8000/8000 [==============================] - 21s 3ms/step - loss: 0.3306 - accuracy: 0.9005 - val_loss: 0.4576 - val_accuracy: 0.8639
# Epoch 17/100
# 8000/8000 [==============================] - 21s 3ms/step - loss: 0.3188 - accuracy: 0.9040 - val_loss: 0.4529 - val_accuracy: 0.8667
# Epoch 18/100
# 8000/8000 [==============================] - 20s 3ms/step - loss: 0.3083 - accuracy: 0.9068 - val_loss: 0.4511 - val_accuracy: 0.8674
# Epoch 19/100
# 8000/8000 [==============================] - 20s 3ms/step - loss: 0.2977 - accuracy: 0.9101 - val_loss: 0.4479 - val_accuracy: 0.8684
# Epoch 20/100
# 8000/8000 [==============================] - 21s 3ms/step - loss: 0.2875 - accuracy: 0.9130 - val_loss: 0.4428 - val_accuracy: 0.8694
# Epoch 21/100
# 8000/8000 [==============================] - 20s 3ms/step - loss: 0.2779 - accuracy: 0.9158 - val_loss: 0.4458 - val_accuracy: 0.8699
# Epoch 22/100
# 8000/8000 [==============================] - 20s 3ms/step - loss: 0.2690 - accuracy: 0.9180 - val_loss: 0.4454 - val_accuracy: 0.8708
# Epoch 23/100
# 8000/8000 [==============================] - 21s 3ms/step - loss: 0.2602 - accuracy: 0.9211 - val_loss: 0.4457 - val_accuracy: 0.8704
# Epoch 24/100
# 8000/8000 [==============================] - 20s 3ms/step - loss: 0.2525 - accuracy: 0.9229 - val_loss: 0.4428 - val_accuracy: 0.8724
# Epoch 25/100
# 8000/8000 [==============================] - 20s 3ms/step - loss: 0.2439 - accuracy: 0.9255 - val_loss: 0.4471 - val_accuracy: 0.8719
# Epoch 26/100
# 8000/8000 [==============================] - 20s 3ms/step - loss: 0.2366 - accuracy: 0.9276 - val_loss: 0.4470 - val_accuracy: 0.8729
# Epoch 27/100
# 8000/8000 [==============================] - 20s 3ms/step - loss: 0.2294 - accuracy: 0.9297 - val_loss: 0.4519 - val_accuracy: 0.8724
# Epoch 28/100
# 8000/8000 [==============================] - 21s 3ms/step - loss: 0.2226 - accuracy: 0.9323 - val_loss: 0.4504 - val_accuracy: 0.8734
# Epoch 29/100
# 8000/8000 [==============================] - 20s 3ms/step - loss: 0.2157 - accuracy: 0.9340 - val_loss: 0.4523 - val_accuracy: 0.8738
# Epoch 30/100
# 8000/8000 [==============================] - 21s 3ms/step - loss: 0.2094 - accuracy: 0.9357 - val_loss: 0.4576 - val_accuracy: 0.8737
# Epoch 31/100
# 8000/8000 [==============================] - 21s 3ms/step - loss: 0.2035 - accuracy: 0.9377 - val_loss: 0.4591 - val_accuracy: 0.8736
# Epoch 32/100
# 8000/8000 [==============================] - 21s 3ms/step - loss: 0.1978 - accuracy: 0.9392 - val_loss: 0.4631 - val_accuracy: 0.8740
# Epoch 33/100
# 8000/8000 [==============================] - 21s 3ms/step - loss: 0.1921 - accuracy: 0.9410 - val_loss: 0.4674 - val_accuracy: 0.8739
# Epoch 34/100
# 8000/8000 [==============================] - 21s 3ms/step - loss: 0.1869 - accuracy: 0.9426 - val_loss: 0.4681 - val_accuracy: 0.8746
# Epoch 35/100
# 8000/8000 [==============================] - 22s 3ms/step - loss: 0.1815 - accuracy: 0.9442 - val_loss: 0.4737 - val_accuracy: 0.8739
# Epoch 36/100
# 8000/8000 [==============================] - 24s 3ms/step - loss: 0.1763 - accuracy: 0.9457 - val_loss: 0.4767 - val_accuracy: 0.8737
# Epoch 37/100
# 8000/8000 [==============================] - 24s 3ms/step - loss: 0.1716 - accuracy: 0.9475 - val_loss: 0.4776 - val_accuracy: 0.8749
# Epoch 38/100
# 8000/8000 [==============================] - 21s 3ms/step - loss: 0.1670 - accuracy: 0.9489 - val_loss: 0.4813 - val_accuracy: 0.8755
# Epoch 39/100
# 8000/8000 [==============================] - 21s 3ms/step - loss: 0.1625 - accuracy: 0.9500 - val_loss: 0.4912 - val_accuracy: 0.8747
# Epoch 40/100
# 8000/8000 [==============================] - 22s 3ms/step - loss: 0.1580 - accuracy: 0.9516 - val_loss: 0.4892 - val_accuracy: 0.8752
# Epoch 41/100
# 8000/8000 [==============================] - 23s 3ms/step - loss: 0.1543 - accuracy: 0.9525 - val_loss: 0.4948 - val_accuracy: 0.8756
# Epoch 42/100
# 8000/8000 [==============================] - 23s 3ms/step - loss: 0.1501 - accuracy: 0.9536 - val_loss: 0.4996 - val_accuracy: 0.8747
# Epoch 43/100
# 8000/8000 [==============================] - 22s 3ms/step - loss: 0.1464 - accuracy: 0.9548 - val_loss: 0.5096 - val_accuracy: 0.8738
# Epoch 44/100
# 8000/8000 [==============================] - 22s 3ms/step - loss: 0.1428 - accuracy: 0.9559 - val_loss: 0.5063 - val_accuracy: 0.8739
# Epoch 45/100
# 8000/8000 [==============================] - 23s 3ms/step - loss: 0.1390 - accuracy: 0.9570 - val_loss: 0.5156 - val_accuracy: 0.8744
# Epoch 46/100
# 8000/8000 [==============================] - 23s 3ms/step - loss: 0.1357 - accuracy: 0.9581 - val_loss: 0.5129 - val_accuracy: 0.8751
# Epoch 47/100
# 8000/8000 [==============================] - 23s 3ms/step - loss: 0.1324 - accuracy: 0.9592 - val_loss: 0.5187 - val_accuracy: 0.8756
# Epoch 48/100
# 8000/8000 [==============================] - 23s 3ms/step - loss: 0.1291 - accuracy: 0.9601 - val_loss: 0.5196 - val_accuracy: 0.8750
# Epoch 49/100
# 8000/8000 [==============================] - 23s 3ms/step - loss: 0.1259 - accuracy: 0.9608 - val_loss: 0.5291 - val_accuracy: 0.8742
# Epoch 50/100
# 8000/8000 [==============================] - 23s 3ms/step - loss: 0.1232 - accuracy: 0.9618 - val_loss: 0.5374 - val_accuracy: 0.8737
# Epoch 51/100
# 8000/8000 [==============================] - 23s 3ms/step - loss: 0.1208 - accuracy: 0.9625 - val_loss: 0.5321 - val_accuracy: 0.8748
# Epoch 52/100
# 8000/8000 [==============================] - 24s 3ms/step - loss: 0.1177 - accuracy: 0.9633 - val_loss: 0.5455 - val_accuracy: 0.8739
# Epoch 53/100
# 8000/8000 [==============================] - 24s 3ms/step - loss: 0.1149 - accuracy: 0.9641 - val_loss: 0.5419 - val_accuracy: 0.8756
# Epoch 54/100
# 8000/8000 [==============================] - 24s 3ms/step - loss: 0.1120 - accuracy: 0.9652 - val_loss: 0.5507 - val_accuracy: 0.8732
# Epoch 55/100
# 8000/8000 [==============================] - 22s 3ms/step - loss: 0.1097 - accuracy: 0.9656 - val_loss: 0.5587 - val_accuracy: 0.8738
# Epoch 56/100
# 8000/8000 [==============================] - 22s 3ms/step - loss: 0.1074 - accuracy: 0.9667 - val_loss: 0.5574 - val_accuracy: 0.8751
# Epoch 57/100
# 8000/8000 [==============================] - 21s 3ms/step - loss: 0.1047 - accuracy: 0.9672 - val_loss: 0.5665 - val_accuracy: 0.8738
# Epoch 58/100
# 8000/8000 [==============================] - 21s 3ms/step - loss: 0.1030 - accuracy: 0.9674 - val_loss: 0.5654 - val_accuracy: 0.8736
# Epoch 59/100
# 8000/8000 [==============================] - 21s 3ms/step - loss: 0.1004 - accuracy: 0.9684 - val_loss: 0.5763 - val_accuracy: 0.8725
# Epoch 60/100
# 8000/8000 [==============================] - 21s 3ms/step - loss: 0.0981 - accuracy: 0.9690 - val_loss: 0.5717 - val_accuracy: 0.8743
# Epoch 61/100
# 8000/8000 [==============================] - 21s 3ms/step - loss: 0.0962 - accuracy: 0.9696 - val_loss: 0.5823 - val_accuracy: 0.8735
# Epoch 62/100
# 8000/8000 [==============================] - 21s 3ms/step - loss: 0.0944 - accuracy: 0.9701 - val_loss: 0.5834 - val_accuracy: 0.8741
# Epoch 63/100
# 8000/8000 [==============================] - 21s 3ms/step - loss: 0.0922 - accuracy: 0.9706 - val_loss: 0.5930 - val_accuracy: 0.8732
# Epoch 64/100
# 8000/8000 [==============================] - 21s 3ms/step - loss: 0.0903 - accuracy: 0.9710 - val_loss: 0.5958 - val_accuracy: 0.8729
# Epoch 65/100
# 8000/8000 [==============================] - 21s 3ms/step - loss: 0.0885 - accuracy: 0.9717 - val_loss: 0.5970 - val_accuracy: 0.8734
# Epoch 66/100
# 8000/8000 [==============================] - 21s 3ms/step - loss: 0.0867 - accuracy: 0.9725 - val_loss: 0.5969 - val_accuracy: 0.8733
# Epoch 67/100
# 8000/8000 [==============================] - 21s 3ms/step - loss: 0.0851 - accuracy: 0.9726 - val_loss: 0.6087 - val_accuracy: 0.8727
# Epoch 68/100
# 8000/8000 [==============================] - 21s 3ms/step - loss: 0.0836 - accuracy: 0.9731 - val_loss: 0.6120 - val_accuracy: 0.8726
# Epoch 69/100
# 8000/8000 [==============================] - 21s 3ms/step - loss: 0.0816 - accuracy: 0.9739 - val_loss: 0.6163 - val_accuracy: 0.8730
# Epoch 70/100
# 8000/8000 [==============================] - 20s 3ms/step - loss: 0.0801 - accuracy: 0.9744 - val_loss: 0.6117 - val_accuracy: 0.8737
# Epoch 71/100
# 8000/8000 [==============================] - 22s 3ms/step - loss: 0.0786 - accuracy: 0.9746 - val_loss: 0.6237 - val_accuracy: 0.8726
# Epoch 72/100
# 8000/8000 [==============================] - 22s 3ms/step - loss: 0.0770 - accuracy: 0.9750 - val_loss: 0.6353 - val_accuracy: 0.8721
# Epoch 73/100
# 8000/8000 [==============================] - 22s 3ms/step - loss: 0.0755 - accuracy: 0.9755 - val_loss: 0.6409 - val_accuracy: 0.8719
# Epoch 74/100
# 8000/8000 [==============================] - 22s 3ms/step - loss: 0.0742 - accuracy: 0.9757 - val_loss: 0.6386 - val_accuracy: 0.8719
# Epoch 75/100
# 8000/8000 [==============================] - 22s 3ms/step - loss: 0.0729 - accuracy: 0.9762 - val_loss: 0.6410 - val_accuracy: 0.8726
# Epoch 76/100
# 8000/8000 [==============================] - 22s 3ms/step - loss: 0.0717 - accuracy: 0.9763 - val_loss: 0.6406 - val_accuracy: 0.8728
# Epoch 77/100
# 8000/8000 [==============================] - 22s 3ms/step - loss: 0.0703 - accuracy: 0.9769 - val_loss: 0.6482 - val_accuracy: 0.8726
# Epoch 78/100
# 8000/8000 [==============================] - 22s 3ms/step - loss: 0.0686 - accuracy: 0.9772 - val_loss: 0.6531 - val_accuracy: 0.8726
# Epoch 79/100
# 8000/8000 [==============================] - 22s 3ms/step - loss: 0.0676 - accuracy: 0.9776 - val_loss: 0.6566 - val_accuracy: 0.8711
# Epoch 80/100
# 8000/8000 [==============================] - 22s 3ms/step - loss: 0.0664 - accuracy: 0.9781 - val_loss: 0.6562 - val_accuracy: 0.8726
# Epoch 81/100
# 8000/8000 [==============================] - 22s 3ms/step - loss: 0.0653 - accuracy: 0.9783 - val_loss: 0.6628 - val_accuracy: 0.8726
# Epoch 82/100
# 8000/8000 [==============================] - 22s 3ms/step - loss: 0.0638 - accuracy: 0.9787 - val_loss: 0.6642 - val_accuracy: 0.8720
# Epoch 83/100
# 8000/8000 [==============================] - 22s 3ms/step - loss: 0.0630 - accuracy: 0.9790 - val_loss: 0.6712 - val_accuracy: 0.8722
# Epoch 84/100
# 8000/8000 [==============================] - 22s 3ms/step - loss: 0.0622 - accuracy: 0.9792 - val_loss: 0.6710 - val_accuracy: 0.8719
# Epoch 85/100
# 8000/8000 [==============================] - 22s 3ms/step - loss: 0.0610 - accuracy: 0.9795 - val_loss: 0.6747 - val_accuracy: 0.8717
# Epoch 86/100
# 8000/8000 [==============================] - 22s 3ms/step - loss: 0.0600 - accuracy: 0.9800 - val_loss: 0.6807 - val_accuracy: 0.8713
# Epoch 87/100
# 8000/8000 [==============================] - 21s 3ms/step - loss: 0.0588 - accuracy: 0.9802 - val_loss: 0.6789 - val_accuracy: 0.8719
# Epoch 88/100
# 8000/8000 [==============================] - 21s 3ms/step - loss: 0.0578 - accuracy: 0.9805 - val_loss: 0.6850 - val_accuracy: 0.8721
# Epoch 89/100
# 8000/8000 [==============================] - 21s 3ms/step - loss: 0.0571 - accuracy: 0.9807 - val_loss: 0.6903 - val_accuracy: 0.8718
# Epoch 90/100
# 8000/8000 [==============================] - 21s 3ms/step - loss: 0.0560 - accuracy: 0.9809 - val_loss: 0.7002 - val_accuracy: 0.8709
# Epoch 91/100
# 8000/8000 [==============================] - 21s 3ms/step - loss: 0.0553 - accuracy: 0.9813 - val_loss: 0.6987 - val_accuracy: 0.8716
# Epoch 92/100
# 8000/8000 [==============================] - 21s 3ms/step - loss: 0.0544 - accuracy: 0.9816 - val_loss: 0.7031 - val_accuracy: 0.8723
# Epoch 93/100
# 8000/8000 [==============================] - 21s 3ms/step - loss: 0.0538 - accuracy: 0.9817 - val_loss: 0.7058 - val_accuracy: 0.8718
# Epoch 94/100
# 8000/8000 [==============================] - 21s 3ms/step - loss: 0.0526 - accuracy: 0.9821 - val_loss: 0.7107 - val_accuracy: 0.8702
# Epoch 95/100
# 8000/8000 [==============================] - 21s 3ms/step - loss: 0.0520 - accuracy: 0.9819 - val_loss: 0.7103 - val_accuracy: 0.8717
# Epoch 96/100
# 8000/8000 [==============================] - 21s 3ms/step - loss: 0.0512 - accuracy: 0.9823 - val_loss: 0.7133 - val_accuracy: 0.8715
# Epoch 97/100
# 8000/8000 [==============================] - 21s 3ms/step - loss: 0.0506 - accuracy: 0.9825 - val_loss: 0.7057 - val_accuracy: 0.8727
# Epoch 98/100
# 8000/8000 [==============================] - 21s 3ms/step - loss: 0.0497 - accuracy: 0.9827 - val_loss: 0.7258 - val_accuracy: 0.8707
# Epoch 99/100
# 8000/8000 [==============================] - 21s 3ms/step - loss: 0.0488 - accuracy: 0.9830 - val_loss: 0.7206 - val_accuracy: 0.8718
# Epoch 100/100
# 8000/8000 [==============================] - 21s 3ms/step - loss: 0.0486 - accuracy: 0.9831 - val_loss: 0.7218 - val_accuracy: 0.8725

# %%
# Next: inference mode (sampling).
# Here's the drill:
# 1) encode input and retrieve initial decoder state
# 2) run one step of decoder with this initial state
# and a "start of sequence" token as target.
# Output will be the next target token
# 3) Repeat with the current target token and current states

# Define sampling models
encoder_model = Model(encoder_inputs, encoder_states)

# %%
decoder_state_input_h = Input(shape=(latent_dim,))
decoder_state_input_c = Input(shape=(latent_dim,))
decoder_states_inputs = [decoder_state_input_h, decoder_state_input_c]
decoder_outputs, state_h, state_c = decoder_lstm(
    decoder_inputs, initial_state=decoder_states_inputs)
decoder_states = [state_h, state_c]
decoder_outputs = decoder_dense(decoder_outputs)
decoder_model = Model(
    [decoder_inputs] + decoder_states_inputs,
    [decoder_outputs] + decoder_states)

# %%
# Reverse-lookup token index to decode sequences back to
# something readable.
reverse_input_char_index = dict(
    (i, char) for char, i in input_token_index.items())
reverse_target_char_index = dict(
    (i, char) for char, i in target_token_index.items())

# %%
def decode_sequence(input_seq):
    # Encode the input as state vectors.
    states_value = encoder_model.predict(input_seq)

    # Generate empty target sequence of length 1.
    target_seq = np.zeros((1, 1, num_decoder_tokens))
    # Populate the first character of target sequence with the start character.
    target_seq[0, 0, target_token_index['\t']] = 1.

    # Sampling loop for a batch of sequences
    # (to simplify, here we assume a batch of size 1).
    stop_condition = False
    decoded_sentence = ''
    while not stop_condition:
        output_tokens, h, c = decoder_model.predict(
            [target_seq] + states_value)

        # Sample a token
        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        sampled_char = reverse_target_char_index[sampled_token_index]
        decoded_sentence += sampled_char

        # Exit condition: either hit max length
        # or find stop character.
        if (sampled_char == '\n' or
           len(decoded_sentence) > max_decoder_seq_length):
            stop_condition = True

        # Update the target sequence (of length 1).
        target_seq = np.zeros((1, 1, num_decoder_tokens))
        target_seq[0, 0, sampled_token_index] = 1.

        # Update states
        states_value = [h, c]

    return decoded_sentence

# %%
for seq_index in range(100):
    # Take one sequence (part of the training set)
    # for trying out decoding.
    input_seq = encoder_input_data[seq_index: seq_index + 1]
    decoded_sentence = decode_sequence(input_seq)
    print('-')
    print('Input sentence:', input_texts[seq_index])
    print('Decoded sentence:', decoded_sentence)
# Out:
# -
# Input sentence: Go.
# Decoded sentence: Va !
#
# -
# Input sentence: Hi.
# Decoded sentence: Salut !
#
# -
# Input sentence: Hi.
# Decoded sentence: Salut !
#
# -
# Input sentence: Run!
# Decoded sentence: Courez !
#
# -
# Input sentence: Run!
# Decoded sentence: Courez !
#
# -
# Input sentence: Who?
# Decoded sentence: Qui ?
#
# -
# Input sentence: Wow!
# Decoded sentence: Ça alors !
#
# -
# Input sentence: Fire!
# Decoded sentence: Au feu !
#
# -
# Input sentence: Help!
# Decoded sentence: À la mienne ?
#
# -
# Input sentence: Jump.
# Decoded sentence: Saute.
#
# -
# Input sentence: Stop!
# Decoded sentence: Arrête-toi !
#
# -
# Input sentence: Stop!
# Decoded sentence: Arrête-toi !
#
# -
# Input sentence: Stop!
# Decoded sentence: Arrête-toi !
#
# -
# Input sentence: Wait!
# Decoded sentence: Attends !
#
# -
# Input sentence: Wait!
# Decoded sentence: Attends !
#
# -
# Input sentence: Go on.
# Decoded sentence: Poursuis.
#
# -
# Input sentence: Go on.
# Decoded sentence: Poursuis.
#
# -
# Input sentence: Go on.
# Decoded sentence: Poursuis.
#
# -
# Input sentence: Hello!
# Decoded sentence: Bonjour !
#
# -
# Input sentence: Hello!
# Decoded sentence: Bonjour !
#
# -
# Input sentence: I see.
# Decoded sentence: Je ne plécrais pas.
#
# -
# Input sentence: I try.
# Decoded sentence: J'essaye.
#
# -
# Input sentence: I won!
# Decoded sentence: Je l'ai emporté !
#
# -
# Input sentence: I won!
# Decoded sentence: Je l'ai emporté !
#
# -
# Input sentence: I won.
# Decoded sentence: J'ai essis ét adoit maid.
#
# -
# Input sentence: Oh no!
# Decoded sentence: Oh non !
#
# -
# Input sentence: Attack!
# Decoded sentence: Attaquez !
#
# -
# Input sentence: Attack!
# Decoded sentence: Attaquez !
#
# -
# Input sentence: Cheers!
# Decoded sentence: Santé !
#
# -
# Input sentence: Cheers!
# Decoded sentence: Santé !
#
# -
# Input sentence: Cheers!
# Decoded sentence: Santé !
#
# -
# Input sentence: Cheers!
# Decoded sentence: Santé !
#
# -
# Input sentence: Get up.
# Decoded sentence: Lève-toi.
#
# -
# Input sentence: Go now.
# Decoded sentence: Vas-y maintenant.
#
# -
# Input sentence: Go now.
# Decoded sentence: Vas-y maintenant.
#
# -
# Input sentence: Go now.
# Decoded sentence: Vas-y maintenant.
#
# -
# Input sentence: Got it!
# Decoded sentence: Compris !
#
# -
# Input sentence: Got it!
# Decoded sentence: Compris !
#
# -
# Input sentence: Got it?
# Decoded sentence: Compris ?
#
# -
# Input sentence: Got it?
# Decoded sentence: Compris ?
#
# -
# Input sentence: Got it?
# Decoded sentence: Compris ?
#
# -
# Input sentence: Hop in.
# Decoded sentence: Monte.
#
# -
# Input sentence: Hop in.
# Decoded sentence: Monte.
#
# -
# Input sentence: Hug me.
# Decoded sentence: Serre-moi dans tes bras !
#
# -
# Input sentence: Hug me.
# Decoded sentence: Serre-moi dans tes bras !
#
# -
# Input sentence: I fell.
# Decoded sentence: Je suis tombée.
#
# -
# Input sentence: I fell.
# Decoded sentence: Je suis tombée.
#
# -
# Input sentence: I know.
# Decoded sentence: Je sais.
#
# -
# Input sentence: I left.
# Decoded sentence: Je suis partie.
#
# -
# Input sentence: I left.
# Decoded sentence: Je suis partie.
#
# -
# Input sentence: I lied.
# Decoded sentence: J'ai menti.
#
# -
# Input sentence: I lost.
# Decoded sentence: J'ai perdu.
#
# -
# Input sentence: I paid.
# Decoded sentence: J’ai payé.
#
# -
# Input sentence: I'm 19.
# Decoded sentence: Je suis triste.
#
# -
# Input sentence: I'm OK.
# Decoded sentence: Je vais bien.
#
# -
# Input sentence: I'm OK.
# Decoded sentence: Je vais bien.
#
# -
# Input sentence: Listen.
# Decoded sentence: Écoutez !
#
# -
# Input sentence: No way!
# Decoded sentence: En aucun cas.
#
# -
# Input sentence: No way!
# Decoded sentence: En aucun cas.
#
# -
# Input sentence: No way!
# Decoded sentence: En aucun cas.
#
# -
# Input sentence: No way!
# Decoded sentence: En aucun cas.
#
# -
# Input sentence: No way!
# Decoded sentence: En aucun cas.
#
# -
# Input sentence: No way!
# Decoded sentence: En aucun cas.
#
# -
# Input sentence: No way!
# Decoded sentence: En aucun cas.
#
# -
# Input sentence: No way!
# Decoded sentence: En aucun cas.
#
# -
# Input sentence: No way!
# Decoded sentence: En aucun cas.
#
# -
# Input sentence: Really?
# Decoded sentence: Vraiment ?
#
# -
# Input sentence: Really?
# Decoded sentence: Vraiment ?
#
# -
# Input sentence: Really?
# Decoded sentence: Vraiment ?
#
# -
# Input sentence: Thanks.
# Decoded sentence: Merci !
#
# -
# Input sentence: We try.
# Decoded sentence: On essaye.
#
# -
# Input sentence: We won.
# Decoded sentence: Nous l'avons emporté.
#
# -
# Input sentence: We won.
# Decoded sentence: Nous l'avons emporté.
#
# -
# Input sentence: We won.
# Decoded sentence: Nous l'avons emporté.
#
# -
# Input sentence: We won.
# Decoded sentence: Nous l'avons emporté.
#
# -
# Input sentence: Ask Tom.
# Decoded sentence: Demande à Tom.
#
# -
# Input sentence: Awesome!
# Decoded sentence: Fantastique !
#
# -
# Input sentence: Be calm.
# Decoded sentence: Soyez calmes !
#
# -
# Input sentence: Be calm.
# Decoded sentence: Soyez calmes !
#
# -
# Input sentence: Be calm.
# Decoded sentence: Soyez calmes !
#
# -
# Input sentence: Be cool.
# Decoded sentence: Sois détendu !
#
# -
# Input sentence: Be fair.
# Decoded sentence: Soyez justes !
#
# -
# Input sentence: Be fair.
# Decoded sentence: Soyez justes !
#
# -
# Input sentence: Be fair.
# Decoded sentence: Soyez justes !
#
# -
# Input sentence: Be fair.
# Decoded sentence: Soyez justes !
#
# -
# Input sentence: Be fair.
# Decoded sentence: Soyez justes !
#
# -
# Input sentence: Be fair.
# Decoded sentence: Soyez justes !
#
# -
# Input sentence: Be kind.
# Decoded sentence: Sois gentil.
#
# -
# Input sentence: Be nice.
# Decoded sentence: Soyez gentil !
#
# -
# Input sentence: Be nice.
# Decoded sentence: Soyez gentil !
#
# -
# Input sentence: Be nice.
# Decoded sentence: Soyez gentil !
#
# -
# Input sentence: Be nice.
# Decoded sentence: Soyez gentil !
#
# -
# Input sentence: Be nice.
# Decoded sentence: Soyez gentil !
#
# -
# Input sentence: Be nice.
# Decoded sentence: Soyez gentil !
#
# -
# Input sentence: Beat it.
# Decoded sentence: Dégage !
#
# -
# Input sentence: Call me.
# Decoded sentence: Appellez-moi !
#
# -
# Input sentence: Call me.
# Decoded sentence: Appellez-moi !
#
# -
# Input sentence: Call us.
# Decoded sentence: Appelle-nous !
#
# -
# Input sentence: Call us.
# Decoded sentence: Appelle-nous !
#
# -
# Input sentence: Come in.
# Decoded sentence: Entre.
